# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/briankimanzi/Documents/Excel/netflix1_python.csv', encoding='ISO-8859-1')
df

# %%
df.shape

# %%
# reading columns
df.columns
# Out:
# Index(['type', 'Unnamed: 2', 'Title_cleaning_Removing_Special_Cases',
#        'director', 'country', 'date_added', 'release_year', 'rating',
#        'duration', 'listed_in', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22'],
#       dtype='object')

# %%
# df.set_index('Show_id_cleaning', inplace=True)
df.reset_index(inplace=True)
df
# Out:
#       level_0  index Show_id_cleaning     type  Unnamed: 2  \
# 0           0      0            ss307    Movie        76.0
# 1           1      1           ss5968    Movie         NaN
# 2           2      2           ss4668    Movie         NaN
# 3           3      3           ss5969    Movie         NaN
# 4           4      4           ss5970    Movie         NaN
# ...       ...    ...              ...      ...         ...
# 8785     8785   8785           ss1833    Movie         NaN
# 8786     8786   8786           ss8807    Movie         NaN
# 8787     8787   8787           ss1957    Movie         NaN
# 8788     8788   8788           ss1774  TV Show         NaN
# 8789     8789   8789           ss2867    Movie         NaN
#
#        Title_cleaning_Removing_Special_Cases           director  \
# 0                                         76         Izu Ojukwu
# 1                                         89          Not Given
# 2                       ââKuch Bheege Alfaaz               Onir
# 3                               âGoli Soda 2       Vijay Milton
# 4                         âMaj Rati ââKeteki  Santwana Bardoloi
# ...                                      ...                ...
# 8785                                    Zozo        Josef Fares
# 8786                                  Zubaan        Mozez Singh
# 8787                       Zulu Man in Japan          Not Given
# 8788                    Zumbos Just Desserts          Not Given
# 8789  ZZ TOP: THAT LITTLE OL BAND FROM TEXAS           Sam Dunn
#
#              country  date_added  release_year  ... Unnamed: 13 Unnamed: 14  \
# 0            Nigeria  08/04/2021          2016  ...         NaN         NaN
# 1     United Kingdom   5/16/2018          2017  ...         NaN         NaN
# 2              India  09/01/2018          2018  ...         NaN         NaN
# 3              India   9/15/2018          2018  ...         NaN         NaN
# 4              India   9/15/2018          2017  ...         NaN         NaN
# ...              ...         ...           ...  ...         ...         ...
# 8785          Sweden  10/19/2020          2005  ...         NaN         NaN
# 8786           India  03/02/2019          2015  ...         NaN         NaN
# 8787        Pakistan   9/25/2020          2019  ...         NaN         NaN
# 8788       Australia  10/31/2020          2019  ...         NaN         NaN
# 8789  United Kingdom  03/01/2020          2019  ...         NaN         NaN
#
#      Unnamed: 15  Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19  \
# 0            NaN          NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN          NaN
# 2            NaN          NaN          NaN          NaN          NaN
# 3            NaN          NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN          NaN
# ...          ...          ...          ...          ...          ...
# 8785         NaN          NaN          NaN          NaN          NaN
# 8786         NaN          NaN          NaN          NaN          NaN
# 8787         NaN          NaN          NaN          NaN          NaN
# 8788         NaN          NaN          NaN          NaN          NaN
# 8789         NaN          NaN          NaN          NaN          NaN
#
#       Unnamed: 20  Unnamed: 21  Unnamed: 22
# 0             NaN          NaN         76.0
# 1             NaN          NaN          NaN
# 2             NaN          NaN          NaN
# 3             NaN          NaN          NaN
# 4             NaN          NaN          NaN
# ...           ...          ...          ...
# 8785          NaN          NaN          NaN
# 8786          NaN          NaN          NaN
# 8787          NaN          NaN          NaN
# 8788          NaN          NaN          NaN
# 8789          NaN          NaN          NaN
#
# [8790 rows x 25 columns]

# %%
df.drop(columns= ['level_0', 'index'], inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df.drop(columns= ['level_0', 'index'], inplace=True)
#       2 df
#
# File /usr/local/Cellar/jupyterlab/4.2.3/libexec/lib/python3.12/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File /usr/local/Cellar/jupyterlab/4.2.3/libexec/lib/python3.12/site-packages/pandas/core/generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File /usr/local/Cellar/jupyterlab/4.2.3/libexec/lib/python3.12/site-packages/pandas/core/generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File /usr/local/Cellar/jupyterlab/4.2.3/libexec/lib/python3.12/site-packages/pandas/core/indexes/base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['level_0', 'index'] not found in axis"

# %%
df['Show_id_cleaning'].sort_values()
# Out:
# 1963       ss1
# 7768      ss10
# 5206     ss100
# 6574    ss1000
# 8602    ss1001
#          ...
# 7958     ss995
# 8396     ss996
# 3127     ss997
# 4055     ss998
# 6136     ss999
# Name: Show_id_cleaning, Length: 8790, dtype: object

# %%
df['Numerical_part'] = df['Show_id_cleaning'].str.extract(r'(\d+)').astype(int)
df = df.sort_values(by='Numerical_part').drop(columns='Numerical_part')
df
# Out:
#      Show_id_cleaning     type  Unnamed: 2  \
# 1963              ss1    Movie         NaN
# 1077              ss2  TV Show         NaN
# 2630              ss3  TV Show         NaN
# 3491              ss4  TV Show         NaN
# 3850              ss5  TV Show         NaN
# ...               ...      ...         ...
# 8776           ss8803    Movie         NaN
# 8779           ss8804  TV Show         NaN
# 8780           ss8805    Movie         NaN
# 8783           ss8806    Movie         NaN
# 8786           ss8807    Movie         NaN
#
#      Title_cleaning_Removing_Special_Cases         director        country  \
# 1963                  Dick Johnson Is Dead  Kirsten Johnson  United States
# 1077                         Blood & Water        Not Given   South Africa
# 2630                             Ganglands  Julien Leclercq         France
# 3491                 Jailbirds New Orleans        Not Given       Pakistan
# 3850                          Kota Factory        Not Given          India
# ...                                    ...              ...            ...
# 8776                                Zodiac    David Fincher  United States
# 8779                           Zombie Dumb        Not Given       Pakistan
# 8780                            Zombieland  Ruben Fleischer  United States
# 8783                                  Zoom     Peter Hewitt  United States
# 8786                                Zubaan      Mozez Singh          India
#
#       date_added  release_year rating   duration  ... Unnamed: 13  \
# 1963   9/25/2021          2020  PG-13     90 min  ...         NaN
# 1077   9/24/2021          2021  TV-MA  2 Seasons  ...         NaN
# 2630   9/24/2021          2021  TV-MA   1 Season  ...         NaN
# 3491   9/24/2021          2021  TV-MA   1 Season  ...         NaN
# 3850   9/24/2021          2021  TV-MA  2 Seasons  ...         NaN
# ...          ...           ...    ...        ...  ...         ...
# 8776  11/20/2019          2007      R    158 min  ...         NaN
# 8779  07/01/2019          2018  TV-Y7  2 Seasons  ...         NaN
# 8780  11/01/2019          2009      R     88 min  ...         NaN
# 8783  01/11/2020          2006     PG     88 min  ...         NaN
# 8786  03/02/2019          2015  TV-14    111 min  ...         NaN
#
#       Unnamed: 14  Unnamed: 15  Unnamed: 16  Unnamed: 17  Unnamed: 18  \
# 1963          NaN          NaN          NaN          NaN          NaN
# 1077          NaN          NaN          NaN          NaN          NaN
# 2630          NaN          NaN          NaN          NaN          NaN
# 3491          NaN          NaN          NaN          NaN          NaN
# 3850          NaN          NaN          NaN          NaN          NaN
# ...           ...          ...          ...          ...          ...
# 8776          NaN          NaN          NaN          NaN          NaN
# 8779          NaN          NaN          NaN          NaN          NaN
# 8780          NaN          NaN          NaN          NaN          NaN
# 8783          NaN          NaN          NaN          NaN          NaN
# 8786          NaN          NaN          NaN          NaN          NaN
#
#       Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22
# 1963          NaN          NaN          NaN          NaN
# 1077          NaN          NaN          NaN          NaN
# 2630          NaN          NaN          NaN          NaN
# 3491          NaN          NaN          NaN          NaN
# 3850          NaN          NaN          NaN          NaN
# ...           ...          ...          ...          ...
# 8776          NaN          NaN          NaN          NaN
# 8779          NaN          NaN          NaN          NaN
# 8780          NaN          NaN          NaN          NaN
# 8783          NaN          NaN          NaN          NaN
# 8786          NaN          NaN          NaN          NaN
#
# [8790 rows x 23 columns]

# %%
# setting the Show_id_cleaning as the index
df.set_index('Show_id_cleaning', inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/6w/_1xx55992tqfg37yz_8bt5v80000gn/T/ipykernel_96256/1732417324.py in ?()
#       1 # setting the Show_id_cleaning as the index
# ----> 2 df.set_index('Show_id_cleaning', inplace=True)
#       3 df
#
# /usr/local/Cellar/jupyterlab/4.2.3/libexec/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['Show_id_cleaning'] are in the columns"

# %%
df.drop(columns='Unnamed: 2', inplace=True)

# %%
# Removing special characters on the title_cleaning_removing_special_case
import re
df['Title_cleaning_Removing_Special_Cases'] = df['Title_cleaning_Removing_Special_Cases'].str.replace(r'[^a-zA-Z0-9]', '', regex=True)

# %%
# Director column
df['director'] = df['director'].str.replace(r'[^a-zA-Z0-9]', '', regex=True)

# %%
df['country']
# Out:
# Show_id_cleaning
# ss1       United States
# ss2        South Africa
# ss3              France
# ss4            Pakistan
# ss5               India
#               ...
# ss8803    United States
# ss8804         Pakistan
# ss8805    United States
# ss8806    United States
# ss8807            India
# Name: country, Length: 8790, dtype: object

# %%
country_grp = df.groupby(['country'])

# %%
country_grp['type'].value_counts().loc['India']
# Out:
# type
# Movie      976
# TV Show     81
# Name: count, dtype: int64

# %%
# date column
df['date_added'] = pd.to_datetime(df['date_added'], format=None)

# %%
# creating a new column that will contain the year only
df['Year_added'] = df['date_added'].dt.year

# %%
# rearranging columns on the data set
rea = df[cols[0:5] + [cols[-1]] + cols[5:20]]
df = rea

# %%
df
# Out:
#                      type Title_cleaning_Removing_Special_Cases  \
# Show_id_cleaning
# ss1                 Movie                     DickJohnsonIsDead
# ss2               TV Show                            BloodWater
# ss3               TV Show                             Ganglands
# ss4               TV Show                   JailbirdsNewOrleans
# ss5               TV Show                           KotaFactory
# ...                   ...                                   ...
# ss8803              Movie                                Zodiac
# ss8804            TV Show                            ZombieDumb
# ss8805              Movie                            Zombieland
# ss8806              Movie                                  Zoom
# ss8807              Movie                                Zubaan
#
#                         director        country date_added  Year_added  \
# Show_id_cleaning
# ss1               KirstenJohnson  United States 2021-09-25        2021
# ss2                     NotGiven   South Africa 2021-09-24        2021
# ss3               JulienLeclercq         France 2021-09-24        2021
# ss4                     NotGiven       Pakistan 2021-09-24        2021
# ss5                     NotGiven          India 2021-09-24        2021
# ...                          ...            ...        ...         ...
# ss8803              DavidFincher  United States 2019-11-20        2019
# ss8804                  NotGiven       Pakistan 2019-07-01        2019
# ss8805            RubenFleischer  United States 2019-11-01        2019
# ss8806               PeterHewitt  United States 2020-01-11        2020
# ss8807                MozezSingh          India 2019-03-02        2019
#
#                   release_year rating   duration  \
# Show_id_cleaning
# ss1                       2020  PG-13     90 min
# ss2                       2021  TV-MA  2 Seasons
# ss3                       2021  TV-MA   1 Season
# ss4                       2021  TV-MA   1 Season
# ss5                       2021  TV-MA  2 Seasons
# ...                        ...    ...        ...
# ss8803                    2007      R    158 min
# ss8804                    2018  TV-Y7  2 Seasons
# ss8805                    2009      R     88 min
# ss8806                    2006     PG     88 min
# ss8807                    2015  TV-14    111 min
#
#                                                           listed_in  ...  \
# Show_id_cleaning                                                     ...
# ss1                                                   Documentaries  ...
# ss2                 International TV Shows, TV Dramas, TV Mysteries  ...
# ss3               Crime TV Shows, International TV Shows, TV Act...  ...
# ss4                                          Docuseries, Reality TV  ...
# ss5               International TV Shows, Romantic TV Shows, TV ...  ...
# ...                                                             ...  ...
# ss8803                               Cult Movies, Dramas, Thrillers  ...
# ss8804                       Kids' TV, Korean TV Shows, TV Comedies  ...
# ss8805                                      Comedies, Horror Movies  ...
# ss8806                           Children & Family Movies, Comedies  ...
# ss8807               Dramas, International Movies, Music & Musicals  ...
#
#                   Unnamed: 12  Unnamed: 13  Unnamed: 14  Unnamed: 15  \
# Show_id_cleaning
# ss1                       NaN          NaN          NaN          NaN
# ss2                       NaN          NaN          NaN          NaN
# ss3                       NaN          NaN          NaN          NaN
# ss4                       NaN          NaN          NaN          NaN
# ss5                       NaN          NaN          NaN          NaN
# ...                       ...          ...          ...          ...
# ss8803                    NaN          NaN          NaN          NaN
# ss8804                    NaN          NaN          NaN          NaN
# ss8805                    NaN          NaN          NaN          NaN
# ss8806                    NaN          NaN          NaN          NaN
# ss8807                    NaN          NaN          NaN          NaN
#
#                   Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19  \
# Show_id_cleaning
# ss1                       NaN          NaN          NaN          NaN
# ss2                       NaN          NaN          NaN          NaN
# ss3                       NaN          NaN          NaN          NaN
# ss4                       NaN          NaN          NaN          NaN
# ss5                       NaN          NaN          NaN          NaN
# ...                       ...          ...          ...          ...
# ss8803                    NaN          NaN          NaN          NaN
# ss8804                    NaN          NaN          NaN          NaN
# ss8805                    NaN          NaN          NaN          NaN
# ss8806                    NaN          NaN          NaN          NaN
# ss8807                    NaN          NaN          NaN          NaN
#
#                   Unnamed: 20  Unnamed: 21
# Show_id_cleaning
# ss1                       NaN          NaN
# ss2                       NaN          NaN
# ss3                       NaN          NaN
# ss4                       NaN          NaN
# ss5                       NaN          NaN
# ...                       ...          ...
# ss8803                    NaN          NaN
# ss8804                    NaN          NaN
# ss8805                    NaN          NaN
# ss8806                    NaN          NaN
# ss8807                    NaN          NaN
#
# [8790 rows x 21 columns]

# %%
# returns all columns containing min
df.loc[df['duration'].str.contains('min')]
# Out:
#                    type Title_cleaning_Removing_Special_Cases  \
# Show_id_cleaning
# ss1               Movie                     DickJohnsonIsDead
# ss7               Movie            MyLittlePonyANewGeneration
# ss8               Movie                               Sankofa
# ss10              Movie                           TheStarling
# ss13              Movie                            JeSuisKarl
# ...                 ...                                   ...
# ss8802            Movie                               Zinzana
# ss8803            Movie                                Zodiac
# ss8805            Movie                            Zombieland
# ss8806            Movie                                  Zoom
# ss8807            Movie                                Zubaan
#
#                                  director               country date_added  \
# Show_id_cleaning
# ss1                        KirstenJohnson         United States 2021-09-25
# ss7               RobertCullenJosLuisUcha             Not Given 2021-09-24
# ss8                           HaileGerima         United States 2021-09-24
# ss10                        TheodoreMelfi         United States 2021-09-24
# ss13                   ChristianSchwochow               Germany 2021-09-23
# ...                                   ...                   ...        ...
# ss8802                      MajidAlAnsari  United Arab Emirates 2016-03-09
# ss8803                       DavidFincher         United States 2019-11-20
# ss8805                     RubenFleischer         United States 2019-11-01
# ss8806                        PeterHewitt         United States 2020-01-11
# ss8807                         MozezSingh                 India 2019-03-02
#
#                   Year_added  release_year rating duration  \
# Show_id_cleaning
# ss1                     2021          2020  PG-13   90 min
# ss7                     2021          2021     PG   91 min
# ss8                     2021          1993  TV-MA  125 min
# ss10                    2021          2021  PG-13  104 min
# ss13                    2021          2021  TV-MA  127 min
# ...                      ...           ...    ...      ...
# ss8802                  2016          2015  TV-MA   96 min
# ss8803                  2019          2007      R  158 min
# ss8805                  2019          2009      R   88 min
# ss8806                  2020          2006     PG   88 min
# ss8807                  2019          2015  TV-14  111 min
#
#                                                          listed_in  ...  \
# Show_id_cleaning                                                    ...
# ss1                                                  Documentaries  ...
# ss7                                       Children & Family Movies  ...
# ss8               Dramas, Independent Movies, International Movies  ...
# ss10                                              Comedies, Dramas  ...
# ss13                                  Dramas, International Movies  ...
# ...                                                            ...  ...
# ss8802                     Dramas, International Movies, Thrillers  ...
# ss8803                              Cult Movies, Dramas, Thrillers  ...
# ss8805                                     Comedies, Horror Movies  ...
# ss8806                          Children & Family Movies, Comedies  ...
# ss8807              Dramas, International Movies, Music & Musicals  ...
#
#                   Unnamed: 12  Unnamed: 13  Unnamed: 14  Unnamed: 15  \
# Show_id_cleaning
# ss1                       NaN          NaN          NaN          NaN
# ss7                       NaN          NaN          NaN          NaN
# ss8                       NaN          NaN          NaN          NaN
# ss10                      NaN          NaN          NaN          NaN
# ss13                      NaN          NaN          NaN          NaN
# ...                       ...          ...          ...          ...
# ss8802                    NaN          NaN          NaN          NaN
# ss8803                    NaN          NaN          NaN          NaN
# ss8805                    NaN          NaN          NaN          NaN
# ss8806                    NaN          NaN          NaN          NaN
# ss8807                    NaN          NaN          NaN          NaN
#
#                   Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19  \
# Show_id_cleaning
# ss1                       NaN          NaN          NaN          NaN
# ss7                       NaN          NaN          NaN          NaN
# ss8                       NaN          NaN          NaN          NaN
# ss10                      NaN          NaN          NaN          NaN
# ss13                      NaN          NaN          NaN          NaN
# ...                       ...          ...          ...          ...
# ss8802                    NaN          NaN          NaN          NaN
# ss8803                    NaN          NaN          NaN          NaN
# ss8805                    NaN          NaN          NaN          NaN
# ss8806                    NaN          NaN          NaN          NaN
# ss8807                    NaN          NaN          NaN          NaN
#
#                   Unnamed: 20  Unnamed: 21
# Show_id_cleaning
# ss1                       NaN          NaN
# ss7                       NaN          NaN
# ss8                       NaN          NaN
# ss10                      NaN          NaN
# ss13                      NaN          NaN
# ...                       ...          ...
# ss8802                    NaN          NaN
# ss8803                    NaN          NaN
# ss8805                    NaN          NaN
# ss8806                    NaN          NaN
# ss8807                    NaN          NaN
#
# [6126 rows x 21 columns]

# %%
df['Minutes']=df['duration'].str.extract(r'(\d+)\s*min\b')[0].dropna().astype(int).astype(str) + ' Min'
# Out:
# /var/folders/6w/_1xx55992tqfg37yz_8bt5v80000gn/T/ipykernel_96256/1424559553.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Minutes']=df['duration'].str.extract(r'(\d+)\s*min\b')[0].dropna().astype(int).astype(str) + ' Min'

# %%
df
# Out:
#                      type Title_cleaning_Removing_Special_Cases  \
# Show_id_cleaning
# ss1                 Movie                     DickJohnsonIsDead
# ss2               TV Show                            BloodWater
# ss3               TV Show                             Ganglands
# ss4               TV Show                   JailbirdsNewOrleans
# ss5               TV Show                           KotaFactory
# ...                   ...                                   ...
# ss8803              Movie                                Zodiac
# ss8804            TV Show                            ZombieDumb
# ss8805              Movie                            Zombieland
# ss8806              Movie                                  Zoom
# ss8807              Movie                                Zubaan
#
#                         director        country date_added  Year_added  \
# Show_id_cleaning
# ss1               KirstenJohnson  United States 2021-09-25        2021
# ss2                     NotGiven   South Africa 2021-09-24        2021
# ss3               JulienLeclercq         France 2021-09-24        2021
# ss4                     NotGiven       Pakistan 2021-09-24        2021
# ss5                     NotGiven          India 2021-09-24        2021
# ...                          ...            ...        ...         ...
# ss8803              DavidFincher  United States 2019-11-20        2019
# ss8804                  NotGiven       Pakistan 2019-07-01        2019
# ss8805            RubenFleischer  United States 2019-11-01        2019
# ss8806               PeterHewitt  United States 2020-01-11        2020
# ss8807                MozezSingh          India 2019-03-02        2019
#
#                   release_year rating   duration  Minutes  ... Unnamed: 12  \
# Show_id_cleaning                                           ...
# ss1                       2020  PG-13     90 min   90 Min  ...         NaN
# ss2                       2021  TV-MA  2 Seasons      NaN  ...         NaN
# ss3                       2021  TV-MA  1 Seasons      NaN  ...         NaN
# ss4                       2021  TV-MA  1 Seasons      NaN  ...         NaN
# ss5                       2021  TV-MA  2 Seasons      NaN  ...         NaN
# ...                        ...    ...        ...      ...  ...         ...
# ss8803                    2007      R    158 min  158 Min  ...         NaN
# ss8804                    2018  TV-Y7  2 Seasons      NaN  ...         NaN
# ss8805                    2009      R     88 min   88 Min  ...         NaN
# ss8806                    2006     PG     88 min   88 Min  ...         NaN
# ss8807                    2015  TV-14    111 min  111 Min  ...         NaN
#
#                   Unnamed: 13  Unnamed: 14  Unnamed: 15  Unnamed: 16  \
# Show_id_cleaning
# ss1                       NaN          NaN          NaN          NaN
# ss2                       NaN          NaN          NaN          NaN
# ss3                       NaN          NaN          NaN          NaN
# ss4                       NaN          NaN          NaN          NaN
# ss5                       NaN          NaN          NaN          NaN
# ...                       ...          ...          ...          ...
# ss8803                    NaN          NaN          NaN          NaN
# ss8804                    NaN          NaN          NaN          NaN
# ss8805                    NaN          NaN          NaN          NaN
# ss8806                    NaN          NaN          NaN          NaN
# ss8807                    NaN          NaN          NaN          NaN
#
#                   Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  \
# Show_id_cleaning
# ss1                       NaN          NaN          NaN          NaN
# ss2                       NaN          NaN          NaN          NaN
# ss3                       NaN          NaN          NaN          NaN
# ss4                       NaN          NaN          NaN          NaN
# ss5                       NaN          NaN          NaN          NaN
# ...                       ...          ...          ...          ...
# ss8803                    NaN          NaN          NaN          NaN
# ss8804                    NaN          NaN          NaN          NaN
# ss8805                    NaN          NaN          NaN          NaN
# ss8806                    NaN          NaN          NaN          NaN
# ss8807                    NaN          NaN          NaN          NaN
#
#                     Seasons
# Show_id_cleaning
# ss1                     NaN
# ss2               2 Seasons
# ss3               1 Seasons
# ss4               1 Seasons
# ss5               2 Seasons
# ...                     ...
# ss8803                  NaN
# ss8804            2 Seasons
# ss8805                  NaN
# ss8806                  NaN
# ss8807                  NaN
#
# [8790 rows x 22 columns]

# %%
cols = list(df.columns)
Min_arr = df[cols[0:9] + [cols[-1]] + cols[9:20]]
Min_arr
# Out:
#                      type Title_cleaning_Removing_Special_Cases  \
# Show_id_cleaning
# ss1                 Movie                     DickJohnsonIsDead
# ss2               TV Show                            BloodWater
# ss3               TV Show                             Ganglands
# ss4               TV Show                   JailbirdsNewOrleans
# ss5               TV Show                           KotaFactory
# ...                   ...                                   ...
# ss8803              Movie                                Zodiac
# ss8804            TV Show                            ZombieDumb
# ss8805              Movie                            Zombieland
# ss8806              Movie                                  Zoom
# ss8807              Movie                                Zubaan
#
#                         director        country date_added  Year_added  \
# Show_id_cleaning
# ss1               KirstenJohnson  United States 2021-09-25        2021
# ss2                     NotGiven   South Africa 2021-09-24        2021
# ss3               JulienLeclercq         France 2021-09-24        2021
# ss4                     NotGiven       Pakistan 2021-09-24        2021
# ss5                     NotGiven          India 2021-09-24        2021
# ...                          ...            ...        ...         ...
# ss8803              DavidFincher  United States 2019-11-20        2019
# ss8804                  NotGiven       Pakistan 2019-07-01        2019
# ss8805            RubenFleischer  United States 2019-11-01        2019
# ss8806               PeterHewitt  United States 2020-01-11        2020
# ss8807                MozezSingh          India 2019-03-02        2019
#
#                   release_year rating   duration    Seasons  ...  \
# Show_id_cleaning                                             ...
# ss1                       2020  PG-13     90 min        NaN  ...
# ss2                       2021  TV-MA  2 Seasons  2 Seasons  ...
# ss3                       2021  TV-MA  1 Seasons  1 Seasons  ...
# ss4                       2021  TV-MA  1 Seasons  1 Seasons  ...
# ss5                       2021  TV-MA  2 Seasons  2 Seasons  ...
# ...                        ...    ...        ...        ...  ...
# ss8803                    2007      R    158 min        NaN  ...
# ss8804                    2018  TV-Y7  2 Seasons  2 Seasons  ...
# ss8805                    2009      R     88 min        NaN  ...
# ss8806                    2006     PG     88 min        NaN  ...
# ss8807                    2015  TV-14    111 min        NaN  ...
#
#                                                           listed_in  \
# Show_id_cleaning
# ss1                                                   Documentaries
# ss2                 International TV Shows, TV Dramas, TV Mysteries
# ss3               Crime TV Shows, International TV Shows, TV Act...
# ss4                                          Docuseries, Reality TV
# ss5               International TV Shows, Romantic TV Shows, TV ...
# ...                                                             ...
# ss8803                               Cult Movies, Dramas, Thrillers
# ss8804                       Kids' TV, Korean TV Shows, TV Comedies
# ss8805                                      Comedies, Horror Movies
# ss8806                           Children & Family Movies, Comedies
# ss8807               Dramas, International Movies, Music & Musicals
#
#                  Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14  \
# Show_id_cleaning
# ss1                      NaN          NaN          NaN          NaN
# ss2                      NaN          NaN          NaN          NaN
# ss3                      NaN          NaN          NaN          NaN
# ss4                      NaN          NaN          NaN          NaN
# ss5                      NaN          NaN          NaN          NaN
# ...                      ...          ...          ...          ...
# ss8803                   NaN          NaN          NaN          NaN
# ss8804                   NaN          NaN          NaN          NaN
# ss8805                   NaN          NaN          NaN          NaN
# ss8806                   NaN          NaN          NaN          NaN
# ss8807                   NaN          NaN          NaN          NaN
#
#                   Unnamed: 15  Unnamed: 16  Unnamed: 17  Unnamed: 18  \
# Show_id_cleaning
# ss1                       NaN          NaN          NaN          NaN
# ss2                       NaN          NaN          NaN          NaN
# ss3                       NaN          NaN          NaN          NaN
# ss4                       NaN          NaN          NaN          NaN
# ss5                       NaN          NaN          NaN          NaN
# ...                       ...          ...          ...          ...
# ss8803                    NaN          NaN          NaN          NaN
# ss8804                    NaN          NaN          NaN          NaN
# ss8805                    NaN          NaN          NaN          NaN
# ss8806                    NaN          NaN          NaN          NaN
# ss8807                    NaN          NaN          NaN          NaN
#
#                   Unnamed: 19
# Show_id_cleaning
# ss1                       NaN
# ss2                       NaN
# ss3                       NaN
# ss4                       NaN
# ss5                       NaN
# ...                       ...
# ss8803                    NaN
# ss8804                    NaN
# ss8805                    NaN
# ss8806                    NaN
# ss8807                    NaN
#
# [8790 rows x 21 columns]

# %%
# seasons
# df['duration'] = df['duration'].str.replace(r'\bSeason\b', 'Seasons', regex=True) # normalizing the season to seasons
df['Seasons'] = df['duration'].str.extract(r'(\d+)\s*Seasons\b').dropna().fillna(0).astype(int).astype(str) + ' Seasons'
# Out:
# /var/folders/6w/_1xx55992tqfg37yz_8bt5v80000gn/T/ipykernel_96256/3031952674.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Seasons'] = df['duration'].str.extract(r'(\d+)\s*Seasons\b')[0].dropna().fillna(0).astype(int).astype(str) + ' Seasons'

# %%
df
# Out:
#                      type Title_cleaning_Removing_Special_Cases  \
# Show_id_cleaning
# ss1                 Movie                     DickJohnsonIsDead
# ss2               TV Show                            BloodWater
# ss3               TV Show                             Ganglands
# ss4               TV Show                   JailbirdsNewOrleans
# ss5               TV Show                           KotaFactory
# ...                   ...                                   ...
# ss8803              Movie                                Zodiac
# ss8804            TV Show                            ZombieDumb
# ss8805              Movie                            Zombieland
# ss8806              Movie                                  Zoom
# ss8807              Movie                                Zubaan
#
#                         director        country date_added  Year_added  \
# Show_id_cleaning
# ss1               KirstenJohnson  United States 2021-09-25        2021
# ss2                     NotGiven   South Africa 2021-09-24        2021
# ss3               JulienLeclercq         France 2021-09-24        2021
# ss4                     NotGiven       Pakistan 2021-09-24        2021
# ss5                     NotGiven          India 2021-09-24        2021
# ...                          ...            ...        ...         ...
# ss8803              DavidFincher  United States 2019-11-20        2019
# ss8804                  NotGiven       Pakistan 2019-07-01        2019
# ss8805            RubenFleischer  United States 2019-11-01        2019
# ss8806               PeterHewitt  United States 2020-01-11        2020
# ss8807                MozezSingh          India 2019-03-02        2019
#
#                   release_year rating   duration  Minutes  ... Unnamed: 12  \
# Show_id_cleaning                                           ...
# ss1                       2020  PG-13     90 min   90 Min  ...         NaN
# ss2                       2021  TV-MA  2 Seasons      NaN  ...         NaN
# ss3                       2021  TV-MA  1 Seasons      NaN  ...         NaN
# ss4                       2021  TV-MA  1 Seasons      NaN  ...         NaN
# ss5                       2021  TV-MA  2 Seasons      NaN  ...         NaN
# ...                        ...    ...        ...      ...  ...         ...
# ss8803                    2007      R    158 min  158 Min  ...         NaN
# ss8804                    2018  TV-Y7  2 Seasons      NaN  ...         NaN
# ss8805                    2009      R     88 min   88 Min  ...         NaN
# ss8806                    2006     PG     88 min   88 Min  ...         NaN
# ss8807                    2015  TV-14    111 min  111 Min  ...         NaN
#
#                   Unnamed: 13  Unnamed: 14  Unnamed: 15  Unnamed: 16  \
# Show_id_cleaning
# ss1                       NaN          NaN          NaN          NaN
# ss2                       NaN          NaN          NaN          NaN
# ss3                       NaN          NaN          NaN          NaN
# ss4                       NaN          NaN          NaN          NaN
# ss5                       NaN          NaN          NaN          NaN
# ...                       ...          ...          ...          ...
# ss8803                    NaN          NaN          NaN          NaN
# ss8804                    NaN          NaN          NaN          NaN
# ss8805                    NaN          NaN          NaN          NaN
# ss8806                    NaN          NaN          NaN          NaN
# ss8807                    NaN          NaN          NaN          NaN
#
#                   Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  \
# Show_id_cleaning
# ss1                       NaN          NaN          NaN          NaN
# ss2                       NaN          NaN          NaN          NaN
# ss3                       NaN          NaN          NaN          NaN
# ss4                       NaN          NaN          NaN          NaN
# ss5                       NaN          NaN          NaN          NaN
# ...                       ...          ...          ...          ...
# ss8803                    NaN          NaN          NaN          NaN
# ss8804                    NaN          NaN          NaN          NaN
# ss8805                    NaN          NaN          NaN          NaN
# ss8806                    NaN          NaN          NaN          NaN
# ss8807                    NaN          NaN          NaN          NaN
#
#                     Seasons
# Show_id_cleaning
# ss1                     NaN
# ss2               2 Seasons
# ss3               1 Seasons
# ss4               1 Seasons
# ss5               2 Seasons
# ...                     ...
# ss8803                  NaN
# ss8804            2 Seasons
# ss8805                  NaN
# ss8806                  NaN
# ss8807                  NaN
#
# [8790 rows x 22 columns]

# %%
colun = list(df.columns)
sea_arr = df[colun[0:8] + [colun[-1]] + colun[8:20]]
sea_arr
# Out:
#                      type Title_cleaning_Removing_Special_Cases  \
# Show_id_cleaning
# ss1                 Movie                     DickJohnsonIsDead
# ss2               TV Show                            BloodWater
# ss3               TV Show                             Ganglands
# ss4               TV Show                   JailbirdsNewOrleans
# ss5               TV Show                           KotaFactory
# ...                   ...                                   ...
# ss8803              Movie                                Zodiac
# ss8804            TV Show                            ZombieDumb
# ss8805              Movie                            Zombieland
# ss8806              Movie                                  Zoom
# ss8807              Movie                                Zubaan
#
#                         director        country date_added  Year_added  \
# Show_id_cleaning
# ss1               KirstenJohnson  United States 2021-09-25        2021
# ss2                     NotGiven   South Africa 2021-09-24        2021
# ss3               JulienLeclercq         France 2021-09-24        2021
# ss4                     NotGiven       Pakistan 2021-09-24        2021
# ss5                     NotGiven          India 2021-09-24        2021
# ...                          ...            ...        ...         ...
# ss8803              DavidFincher  United States 2019-11-20        2019
# ss8804                  NotGiven       Pakistan 2019-07-01        2019
# ss8805            RubenFleischer  United States 2019-11-01        2019
# ss8806               PeterHewitt  United States 2020-01-11        2020
# ss8807                MozezSingh          India 2019-03-02        2019
#
#                   release_year rating    Seasons   duration  ...  \
# Show_id_cleaning                                             ...
# ss1                       2020  PG-13        NaN     90 min  ...
# ss2                       2021  TV-MA  2 Seasons  2 Seasons  ...
# ss3                       2021  TV-MA  1 Seasons  1 Seasons  ...
# ss4                       2021  TV-MA  1 Seasons  1 Seasons  ...
# ss5                       2021  TV-MA  2 Seasons  2 Seasons  ...
# ...                        ...    ...        ...        ...  ...
# ss8803                    2007      R        NaN    158 min  ...
# ss8804                    2018  TV-Y7  2 Seasons  2 Seasons  ...
# ss8805                    2009      R        NaN     88 min  ...
# ss8806                    2006     PG        NaN     88 min  ...
# ss8807                    2015  TV-14        NaN    111 min  ...
#
#                                                           listed_in  \
# Show_id_cleaning
# ss1                                                   Documentaries
# ss2                 International TV Shows, TV Dramas, TV Mysteries
# ss3               Crime TV Shows, International TV Shows, TV Act...
# ss4                                          Docuseries, Reality TV
# ss5               International TV Shows, Romantic TV Shows, TV ...
# ...                                                             ...
# ss8803                               Cult Movies, Dramas, Thrillers
# ss8804                       Kids' TV, Korean TV Shows, TV Comedies
# ss8805                                      Comedies, Horror Movies
# ss8806                           Children & Family Movies, Comedies
# ss8807               Dramas, International Movies, Music & Musicals
#
#                  Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14  \
# Show_id_cleaning
# ss1                      NaN          NaN          NaN          NaN
# ss2                      NaN          NaN          NaN          NaN
# ss3                      NaN          NaN          NaN          NaN
# ss4                      NaN          NaN          NaN          NaN
# ss5                      NaN          NaN          NaN          NaN
# ...                      ...          ...          ...          ...
# ss8803                   NaN          NaN          NaN          NaN
# ss8804                   NaN          NaN          NaN          NaN
# ss8805                   NaN          NaN          NaN          NaN
# ss8806                   NaN          NaN          NaN          NaN
# ss8807                   NaN          NaN          NaN          NaN
#
#                   Unnamed: 15  Unnamed: 16  Unnamed: 17  Unnamed: 18  \
# Show_id_cleaning
# ss1                       NaN          NaN          NaN          NaN
# ss2                       NaN          NaN          NaN          NaN
# ss3                       NaN          NaN          NaN          NaN
# ss4                       NaN          NaN          NaN          NaN
# ss5                       NaN          NaN          NaN          NaN
# ...                       ...          ...          ...          ...
# ss8803                    NaN          NaN          NaN          NaN
# ss8804                    NaN          NaN          NaN          NaN
# ss8805                    NaN          NaN          NaN          NaN
# ss8806                    NaN          NaN          NaN          NaN
# ss8807                    NaN          NaN          NaN          NaN
#
#                   Unnamed: 19
# Show_id_cleaning
# ss1                       NaN
# ss2                       NaN
# ss3                       NaN
# ss4                       NaN
# ss5                       NaN
# ...                       ...
# ss8803                    NaN
# ss8804                    NaN
# ss8805                    NaN
# ss8806                    NaN
# ss8807                    NaN
#
# [8790 rows x 21 columns]

# %%
# droping unnecessary columns
df.drop(['Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 
        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 
        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20'],
       axis=1, inplace=True)
# Out:
# /var/folders/6w/_1xx55992tqfg37yz_8bt5v80000gn/T/ipykernel_96256/372734881.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',

# %%
df.drop('Unnamed: 11', axis=1)
# Out:
#                      type Title_cleaning_Removing_Special_Cases  \
# Show_id_cleaning
# ss1                 Movie                     DickJohnsonIsDead
# ss2               TV Show                            BloodWater
# ss3               TV Show                             Ganglands
# ss4               TV Show                   JailbirdsNewOrleans
# ss5               TV Show                           KotaFactory
# ...                   ...                                   ...
# ss8803              Movie                                Zodiac
# ss8804            TV Show                            ZombieDumb
# ss8805              Movie                            Zombieland
# ss8806              Movie                                  Zoom
# ss8807              Movie                                Zubaan
#
#                         director        country date_added  Year_added  \
# Show_id_cleaning
# ss1               KirstenJohnson  United States 2021-09-25        2021
# ss2                     NotGiven   South Africa 2021-09-24        2021
# ss3               JulienLeclercq         France 2021-09-24        2021
# ss4                     NotGiven       Pakistan 2021-09-24        2021
# ss5                     NotGiven          India 2021-09-24        2021
# ...                          ...            ...        ...         ...
# ss8803              DavidFincher  United States 2019-11-20        2019
# ss8804                  NotGiven       Pakistan 2019-07-01        2019
# ss8805            RubenFleischer  United States 2019-11-01        2019
# ss8806               PeterHewitt  United States 2020-01-11        2020
# ss8807                MozezSingh          India 2019-03-02        2019
#
#                   release_year rating   duration  Minutes  \
# Show_id_cleaning
# ss1                       2020  PG-13     90 min   90 Min
# ss2                       2021  TV-MA  2 Seasons      NaN
# ss3                       2021  TV-MA  1 Seasons      NaN
# ss4                       2021  TV-MA  1 Seasons      NaN
# ss5                       2021  TV-MA  2 Seasons      NaN
# ...                        ...    ...        ...      ...
# ss8803                    2007      R    158 min  158 Min
# ss8804                    2018  TV-Y7  2 Seasons      NaN
# ss8805                    2009      R     88 min   88 Min
# ss8806                    2006     PG     88 min   88 Min
# ss8807                    2015  TV-14    111 min  111 Min
#
#                                                           listed_in    Seasons
# Show_id_cleaning
# ss1                                                   Documentaries        NaN
# ss2                 International TV Shows, TV Dramas, TV Mysteries  2 Seasons
# ss3               Crime TV Shows, International TV Shows, TV Act...  1 Seasons
# ss4                                          Docuseries, Reality TV  1 Seasons
# ss5               International TV Shows, Romantic TV Shows, TV ...  2 Seasons
# ...                                                             ...        ...
# ss8803                               Cult Movies, Dramas, Thrillers        NaN
# ss8804                       Kids' TV, Korean TV Shows, TV Comedies  2 Seasons
# ss8805                                      Comedies, Horror Movies        NaN
# ss8806                           Children & Family Movies, Comedies        NaN
# ss8807               Dramas, International Movies, Music & Musicals        NaN
#
# [8790 rows x 12 columns]

# %%
# listed in column
listed_in_grp = df.groupby('listed_in')

# %%
listed_in_grp.get_group('')

# %%
listed_in_grp['listed_in'].loc['Dramas']
